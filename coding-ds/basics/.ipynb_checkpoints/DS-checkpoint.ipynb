# %%
import sys
import matplotlib
# %matplotlib inline 
# matplotlib.use('Agg')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import numpy as np

# %%
data = pd.read_csv('data.csv', header=0, sep=',')

# %%
data
# Out:
#      Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0          60            110        130              409         0.0
# 1          60            117        145              479         0.0
# 2          60            103        135              340         8.0
# 3          45            109        175              282         8.0
# 4          45            117        148              406         0.0
# ..        ...            ...        ...              ...         ...
# 158        60            105        140              290         7.0
# 159        60            110        145              300         7.0
# 160        60            115        145              310         8.0
# 161        75            120        150              320         0.0
# 162        75            125        150              330         8.0
#
#      Hours_Sleep
# 0            8.0
# 1            8.0
# 2            7.5
# 3            8.0
# 4            6.5
# ..           ...
# ...

# %%
x = data['Average_Pulse']
y = data['Calorie_Burnage']
stats.linregress(x, y)
# Out:
# LinregressResult(slope=0.3295634736556584, intercept=346.8662267857687, rvalue=0.017576257945091014, pvalue=0.8237776479944344, stderr=1.477517466577579, intercept_stderr=160.61521830559641)

# %%
slope, intercept, corr_coefficient, p, std_err = stats.linregress(x, y)

# %%
slope, intercept, corr_coefficient, p, std_err
# Out:
# (0.3295634736556584,
#  346.8662267857687,
#  0.017576257945091014,
#  0.8237776479944344,
#  1.477517466577579)

# %%
def myfunc(x):
    return slope * x + intercept

# %%
mymodel = list(map(myfunc, x))
mymodel
# Out:
# [383.1182088878911,
#  385.4251532034807,
#  380.81126457230147,
#  382.7886454142354,
#  385.4251532034807,
#  380.48170109864583,
#  383.1182088878911,
#  381.14082804595716,
#  382.7886454142354,
#  379.1634472040232,
#  380.81126457230147,
#  379.8225741513345,
#  381.79995499326844,
#  381.14082804595716,
#  379.1634472040232,
#  379.1634472040232,
#  379.8225741513345,
#  376.5269394147779,
#  380.81126457230147,
#  378.8338837303675,
#  382.4590819405798,
#  379.8225741513345,
#  389.70947836100424,
#  381.4703915196128,
#  380.48170109864583,
#  379.8225741513345,
#  377.18606636208926,
#  380.81126457230147,
#  379.8225741513345,
#  380.48170109864583,
#  377.18606636208926,
#  380.1521376249902,
#  377.5156298357449,
#  382.12951846692414,
#  384.43646278251373,
#  379.8225741513345,
#  379.8225741513345,
#  381.14082804595716,
#  379.1634472040232,
#  379.8225741513345,
#  383.44777236154675,
#  383.44777236154675,
#  379.49301067767885,
#  382.7886454142354,
# ...

# %%
# plt.switch_backend('TkAgg')
plt.scatter(x, y)
plt.plot(x, mymodel)
plt.ylim(ymin=0, ymax=2000)
plt.xlim(xmin=0, xmax=200)
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.show()

# %%
dictionary = {
    'col1': [1, 2, 3, 4, 5],
    'col2': [6, 7, 8, 9, 10],
    'col3': [11, 1, 2 ,34, 4]
}
df = pd.DataFrame(data=dictionary)
df
# Out:
#    col1  col2  col3
# 0     1     6    11
# 1     2     7     1
# 2     3     8     2
# 3     4     9    34
# 4     5    10     4

# %%
count_column = df.shape[1]
count_row = df.shape[0]
print(count_column)
count_row
# Out:
# 3
# 5

# %%
Calorie_burnage = data['Calorie_Burnage']
np.mean(Calorie_burnage)
# Out:
# 382.3680981595092

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Duration         163 non-null    int64
#  1   Average_Pulse    163 non-null    int64
#  2   Max_Pulse        163 non-null    int64
#  3   Calorie_Burnage  163 non-null    int64
#  4   Hours_Work       163 non-null    float64
#  5   Hours_Sleep      163 non-null    float64
# dtypes: float64(2), int64(4)
# memory usage: 7.8 KB

# %%
data.describe()
# Out:
#          Duration  Average_Pulse   Max_Pulse  Calorie_Burnage  Hours_Work  \
# count  163.000000     163.000000  163.000000       163.000000  163.000000
# mean    64.263804     107.723926  134.226994       382.368098    4.386503
# std     42.994520      14.625062   16.403967       274.227106    3.923772
# min     15.000000      80.000000  100.000000        50.000000    0.000000
# 25%     45.000000     100.000000  124.000000       256.500000    0.000000
# 50%     60.000000     105.000000  131.000000       320.000000    5.000000
# 75%     60.000000     111.000000  141.000000       388.500000    8.000000
# max    300.000000     159.000000  184.000000      1860.000000   11.000000
#
#        Hours_Sleep
# count   163.000000
# mean      7.680982
# std       0.663934
# min       5.000000
# 25%       7.500000
# 50%       8.000000
# 75%       8.000000
# max      12.000000

# %%
columns_of_int_type = data.select_dtypes(include='int64')
columns_of_int_type
# Out:
#      Duration  Average_Pulse  Max_Pulse  Calorie_Burnage
# 0          60            110        130              409
# 1          60            117        145              479
# 2          60            103        135              340
# 3          45            109        175              282
# 4          45            117        148              406
# ..        ...            ...        ...              ...
# 158        60            105        140              290
# 159        60            110        145              300
# 160        60            115        145              310
# 161        75            120        150              320
# 162        75            125        150              330
#
# [163 rows x 4 columns]

# %%
data
# Out:
#      Duration  Average_Pulse  Max_Pulse  Calorie_Burnage  Hours_Work  \
# 0          60            110        130              409         0.0
# 1          60            117        145              479         0.0
# 2          60            103        135              340         8.0
# 3          45            109        175              282         8.0
# 4          45            117        148              406         0.0
# ..        ...            ...        ...              ...         ...
# 158        60            105        140              290         7.0
# 159        60            110        145              300         7.0
# 160        60            115        145              310         8.0
# 161        75            120        150              320         0.0
# 162        75            125        150              330         8.0
#
#      Hours_Sleep
# 0            8.0
# 1            8.0
# 2            7.5
# 3            8.0
# 4            6.5
# ..           ...
# ...

# %%
x, y
# Out:
# (0      110
#  1      117
#  2      103
#  3      109
#  4      117
#        ...
#  158    105
#  159    110
#  160    115
#  161    120
#  162    125
#  Name: Average_Pulse, Length: 163, dtype: int64,
#  0      409
#  1      479
#  2      340
#  3      282
#  4      406
#        ...
#  158    290
#  159    300
#  160    310
#  161    320
#  162    330
#  Name: Calorie_Burnage, Length: 163, dtype: int64)

# %%
slope_intercept = np.polyfit(x, y, 1)
slope_intercept
# Out:
# array([3.29563474e-01, 3.46866227e+02])

# %%
columns_of_int_type.astype(float)
# Out:
#      Duration  Average_Pulse  Max_Pulse  Calorie_Burnage
# 0        60.0          110.0      130.0            409.0
# 1        60.0          117.0      145.0            479.0
# 2        60.0          103.0      135.0            340.0
# 3        45.0          109.0      175.0            282.0
# 4        45.0          117.0      148.0            406.0
# ..        ...            ...        ...              ...
# 158      60.0          105.0      140.0            290.0
# 159      60.0          110.0      145.0            300.0
# 160      60.0          115.0      145.0            310.0
# 161      75.0          120.0      150.0            320.0
# 162      75.0          125.0      150.0            330.0
#
# [163 rows x 4 columns]

# %%
data.describe()
# Out:
#          Duration  Average_Pulse   Max_Pulse  Calorie_Burnage  Hours_Work  \
# count  163.000000     163.000000  163.000000       163.000000  163.000000
# mean    64.263804     107.723926  134.226994       382.368098    4.386503
# std     42.994520      14.625062   16.403967       274.227106    3.923772
# min     15.000000      80.000000  100.000000        50.000000    0.000000
# 25%     45.000000     100.000000  124.000000       256.500000    0.000000
# 50%     60.000000     105.000000  131.000000       320.000000    5.000000
# 75%     60.000000     111.000000  141.000000       388.500000    8.000000
# max    300.000000     159.000000  184.000000      1860.000000   11.000000
#
#        Hours_Sleep
# count   163.000000
# mean      7.680982
# std       0.663934
# min       5.000000
# 25%       7.500000
# 50%       8.000000
# 75%       8.000000
# max      12.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163 entries, 0 to 162
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Duration         163 non-null    int64
#  1   Average_Pulse    163 non-null    int64
#  2   Max_Pulse        163 non-null    int64
#  3   Calorie_Burnage  163 non-null    int64
#  4   Hours_Work       163 non-null    float64
#  5   Hours_Sleep      163 non-null    float64
# dtypes: float64(2), int64(4)
# memory usage: 7.8 KB

# %%
Max_Pulse = data['Max_Pulse']
percentile10 = np.percentile(Max_Pulse, 10)
percentile10
# Out:
# 120.0

# %% [markdown]
# The `10%` percentile of `Max_Pulse` is 120. This means that 10% of all training sessions have a `Max_Pulse` of 120 or lower.

# %%
std = np.std(data)
std
# Out:
# Duration            42.862432
# Average_Pulse       14.580131
# Max_Pulse           16.353571
# Calorie_Burnage    273.384624
# Hours_Work           3.911718
# Hours_Sleep          0.661895
# dtype: float64

# %% [markdown]
# Coefficient of Variation - how large standard deviation is:
# $$
# \text{Coefficient of VAriantion} = \frac{\text{Standard Deviation}}{\text{Mean}}
# $$
